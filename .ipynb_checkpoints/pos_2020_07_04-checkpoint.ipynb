# %%
import numpy as np
import pandas as pd

# %%
def split_lines(lines):
    words=[]
    tags=[]
    for line in lines.split("\n"):
        if line=="":
            continue
        w=line.split()[0]
        if(w.find("'")!=-1):
            words.append(w[:w.find("'")])
            tags.append(line.split()[1])
            words.append(w[w.find("'"):])
            tags.append("")
        else:
            words.append(w)
            tags.append(line.split()[1])
    return words, tags

# %%
def find_tag(tag):
    start=tag.find("+")+1
    if tag[start:].find("+")==-1:
        tag=tag[start:]
    else:
        end=tag[start:].find("+")+start
        tag=tag[start:end]
    return tag

# %%
def change_tag(tag_list):
    turkish_tag_list_adj = ["AFutPart","APastPart","APresPart","Adj"]
    turkish_tag_list_noun = ["NFutPart","NPastPart","NPresPart","NInf","Noun","Prop"]
    turkish_tag_list_num = ["Card","Distrib","Num","Ord","Range","Real"]
    turkish_tag_list_pron = ["DemonsP","PersP","Pron","QuesP","ReflexP"]
    turkish_tag_list_pun = ["Punc","Ques"]
    turkish_tag_list_verb = ["Verb","Zero"]
    
    
    for i, w in enumerate(tag_list):
        if w in turkish_tag_list_adj:
            tag_list[i] = "ADJ"
        if w in turkish_tag_list_noun:
            tag_list[i] = "NOUN"
        if w in turkish_tag_list_num:
            tag_list[i] = "NUM"
        if w in turkish_tag_list_pron:
            tag_list[i] = "PRON"
        if w in turkish_tag_list_pun:
            tag_list[i] = "."
        if w in turkish_tag_list_verb:
            tag_list[i] = "VERB"
        if w == "Adverb":
            tag_list[i] = "ADV"
        if w == "Conj":
            tag_list[i] = "CONJ"
        if w == "Det":
            tag_list[i] = "DET"
        if w == "Dup":
            tag_list[i] = "PRT"
        if w == "Interj":
            tag_list[i] = "X"
        if w == "Postp":
            tag_list[i] = "ADP"
        
    return tag_list

# %%
def tag(doc_no, filename):
    file = open(filename, "r")
    f=file.read()
    words, tags=split_lines(f)
    doc={"doc_no":[], "sentence_no":[], "word":[], "tag":[]}
    sentence_no=0
    for i in range(len(words)):
        if(words[i]!=""):
            if words[i]!="</S>" and words[i]!="<S>": 
                doc["doc_no"].append(doc_no)
                doc["sentence_no"].append(sentence_no)
                doc["word"].append(words[i])
                doc["tag"].append(find_tag(tags[i]))
                if(words[i].find(".")!=-1 or words[i].find("?")!=-1 or words[i].find("!")!=-1):
                    sentence_no+=1
    return doc

# %%
doc=tag(doc_no=1400, filename="kultur1_etiketli.txt")

# %%
df=pd.DataFrame(doc)
df
# Out:
#      doc_no  sentence_no           word    tag
# 0      1400            0             Su   Noun
# 1      1400            0        altının   Noun
# 2      1400            0            son    Adj
# 3      1400            0             60    Adj
# 4      1400            0           yılı   Noun
# ..      ...          ...            ...    ...
# 139    1400            5          Şubat   Noun
# 140    1400            5             'a
# 141    1400            5          kadar  Postp
# 142    1400            5        ziyaret   Noun
# 143    1400            5  edilebilecek.  Guess
#
# [144 rows x 4 columns]

# %%
df["new_tag"]=change_tag(df.tag.copy())
df[30:50]
# Out:
#     doc_no  sentence_no         word     tag new_tag
# 30    1400            1         'nde
# 31    1400            1    açılacak.   Guess   Guess
# 32    1400            2           60     Adj     ADJ
# 33    1400            2       yıllık     Adj     ADJ
# 34    1400            2          bir  Adverb     ADV
# 35    1400            2    hikayenin    Noun    NOUN
# 36    1400            2  anlatıldığı    Verb    VERB
# 37    1400            2     sergide,   Guess   Guess
# 38    1400            2      Türkiye    Noun    NOUN
# 39    1400            2          'de
# 40    1400            2           su    Noun    NOUN
# 41    1400            2      altında    Noun    NOUN
# 42    1400            2          ilk     Adj     ADJ
# 43    1400            2          kez    Noun    NOUN
# 44    1400            2   deklanşöre    Noun    NOUN
# 45    1400            2        basan    Noun    NOUN
# 46    1400            2        Rasim    Noun    NOUN
# 47    1400            2     Divanlı,       ?       ?
# 48    1400            2      Mustafa    Noun    NOUN
# 49    1400            2      Kapkın,       ?       ?
